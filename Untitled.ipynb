# %% [markdown]
# # CAPSTONE PROJECT
# ### This notebook contains all the code for Location Segmentation Project

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Hello Capstone Project Course!
